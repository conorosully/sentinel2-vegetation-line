# %%
#from SCA import SCA
#from DOD import DOD
#from DataImportandTransectDefinition import DataImportandTransectDefinition 
import PyShoreVolume as psv
import geopandas as gpd

#intersects = gpd.read_file(r'../data/QGIS/PyShoreVolume/intersect.shp')
#transects = gpd.read_file(r'../data/QGIS/PyShoreVolume/transect.shp')
intersects = gpd.read_file(r'../../PyShoreVolume/PyShoreVolume/Extra/Intersections2.shp')
transects = gpd.read_file(r'../../PyShoreVolume/PyShoreVolume/Extra/Transect1.shp')

# %%
#Georeferencing and measurment errors of each shoreline in meters. 
georefs = [1, 0.8, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4]
measurement = [1, 1, 1, 1, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]

path = r'../data/QGIS/PyShoreVolume/shorelines.shp'

#Set the cleaning configuration
Datacleaning = psv.DataImportandTransectDefinition(CRS = 4326, 
                                                   intersects = intersects, 
                                                   transects = transects, 
                                                   path = path,
                                                   georeferror=georefs, 
                                                   measurementerror=measurement)

# %%
#Assign seaward transect coordinates to intersection dataframe (Check coordinates plot)
Datacleaning.transectstartlocator1()

#Remove duplicate shoreline points
Datacleaning.cleaning()

#Add georeferencing and measurement errors for each shorleine to dataframe and save newly configured intersection file to variable. 
intersectiondata = Datacleaning.errors()

#Create and save path to results folder to be set as a parameter in the SCA functions.
results = Datacleaning.results()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       2 Datacleaning.transectstartlocator1()
#       4 #Remove duplicate shoreline points
# ----> 5 Datacleaning.cleaning()
#       7 #Add georeferencing and measurement errors for each shorleine to dataframe and save newly configured intersection file to variable.
#       8 intersectiondata = Datacleaning.errors()
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/PyShoreVolume/DataImportandTransectDefinition1.py:38, in DataImportandTransectDefinition.cleaning(self)
#      37 def cleaning(self):
# ---> 38     self.intersects = cleaning(self.intersects)
#      39     return self.intersects
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/PyShoreVolume/CleanandTransectLocator/DataCleaning.py:98, in cleaning(intersected)
#      96        ##tr - transect geometry point
#      97        tr = s
# ---> 98        tr = tr.set_geometry('geometry_y').to_crs(epsg=3857)
#      99        uniquelayer = s['layer'].drop_duplicates()
#     100        #print(tr, uniquelayer)
#     101
#     102 ####Iterate through the available years taking the intersect closest to baseline first
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/geopandas/geodataframe.py:1701, in GeoDataFrame.to_crs(self, crs, epsg, inplace)
#    1699 else:
#    1700     df = self.copy()
# -> 1701 geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1702 df.geometry = geom
#    1703 if not inplace:
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/geopandas/geoseries.py:1207, in GeoSeries.to_crs(self, crs, epsg)
#    1128 def to_crs(
#    1129     self, crs: Optional[Any] = None, epsg: Optional[int] = None
#    1130 ) -> GeoSeries:
#    1131     """Returns a ``GeoSeries`` with all geometries transformed to a new
#    1132     coordinate reference system.
#    1133
#    (...)   1204
#    1205     """
#    1206     return GeoSeries(
# -> 1207         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1208     )
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/geopandas/_compat.py:90, in requires_pyproj.<locals>.wrapper(*args, **kwargs)
#      84 if not HAS_PYPROJ:
#      85     raise ImportError(
#      86         f"The 'pyproj' package is required for {func.__name__} to work. "
#      87         "Install it and initialize the object with a CRS before using it."
#      88         f"\nImporting pyproj resulted in: {pyproj_import_error}"
#      89     )
# ---> 90 return func(*args, **kwargs)
#
# File ~/Documents/git/COASTAL_MONITORING/sentinel2-irish-coastal-segmentation/SICS/lib/python3.11/site-packages/geopandas/array.py:1002, in GeometryArray.to_crs(self, crs, epsg)
#     999 from pyproj import CRS
#    1001 if self.crs is None:
# -> 1002     raise ValueError(
#    1003         "Cannot transform naive geometries.  "
#    1004         "Please set a crs on the object first."
#    1005     )
#    1006 if crs is not None:
#    1007     crs = CRS.from_user_input(crs)
#
# ValueError: Cannot transform naive geometries.  Please set a crs on the object first.
